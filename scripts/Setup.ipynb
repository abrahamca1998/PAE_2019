# %%
##Set-up
# Import the libraries 
import re
import os
import numpy as np
import json
import matplotlib.pyplot as plt
from PIL import Image

def read_json(file):
    
    ## Read the json file
    #Inputs=name of json file(all path)
    
    with open(file, 'r') as myfile:
        data=myfile.read()
    obj = json.loads(data)
    filejson=str(obj.get('lines'))
    
    #Establish patterns in order to obtain the features of each 
    
    x_pattern="'x': (.*?),"
    y_pattern="'y': (.*?)}"
    force_pattern="'force': (.*?),"
    altitude_angle_pattern="'altitude_angle': (.*?),"
    azimuth_angle_pattern="'azimuth_angle': (.*?),"
    timestamp_pattern="'timestamp': (.*?),"
    
    # Find the features
    
    x=re.findall(x_pattern,filejson)
    y=re.findall(y_pattern,filejson)
    force=re.findall(force_pattern,filejson)
    altitude_angle=re.findall(altitude_angle_pattern,filejson)
    azimuth_angle=re.findall(azimuth_angle_pattern,filejson)
    timestamp=re.findall(timestamp_pattern,filejson)
    
    # Convert the features in numpy array to ease to facilitate the task of the predictive model
    x=np.array([float(i) for i in x])
    y=np.array([float(i) for i in y])
    force=np.array([float(i) for i in force])
    altitude_angle=np.array([float(i) for i in altitude_angle])
    azimuth_angle=np.array([float(i) for i in azimuth_angle])
    timestamp=np.array([float(i) for i in timestamp])
    
    return x,y,force,altitude_angle,azimuth_angle,timestamp
    
def search_json_files_Clock_Test(currentpath):
    ##This function returns all of the json files related to the clock drawing test.
    
    ##Change the current path to your path
    
    os.chdir(currentpath)
    
    #Search and save all paths of the files.
    
    paths=[]
    for root, dirs, files in os.walk(".", topdown=False):
            for name in files:
                paths.append(os.path.join(root, name))
            for name in dirs:
                paths.append(os.path.join(root, name))
   
    ## Patterns to search only the paths of the CDT files.
    pattern1="(/mad pencil y trazo/patientID_.*?/testID_.*?/.*?-CD-.*?-.*?-[0-9].json)"
    pattern2=".(/mad pencil y trazo/patientID_.*?/testID_.*?/.*?-CD-.*?-.*?-migrated.json)"
    pattern3="[^o](/patientID_.*?/testID_.*?/.*?-CD-.*?-.*?-[0-9].json)"
    patterns=[pattern1,pattern2,pattern3]
    
    ##Save the name of json files that complish the pattern
    
    json_files=[]
    for path in paths:
        for pattern in patterns:
            b=re.findall(pattern,path)
            if b:
                json_files.append(b)
                
   
    ##Clean the paths.
    
    path=currentpath+"{}"
    json_files=[str(i) for i in json_files]
    json_files=[i.replace(']','') for i in json_files]
    json_files=[i.replace('[','') for i in json_files]
    json_files=[i.replace("'","") for i in json_files]
    json_files=[path.format(i) for i in json_files]
    #for json_file in json_files:
    #   shutil.copy(json_file,'/home/abraham/Escritorio/PAE/numberdetection/PENCIL TRAZO Y RELOJ/samples')
        
    
    return json_files
def clean_empties_json(json_files):
    for json_file in json_files:
        x,_,_,_,_,_=read_json(json_file)
        if x.size==0:
            json_files.remove(json_file)    


def CDT_to_image(json_file,pattern,image_format):
    name="{}{}"
    x,y,_,_,_,_=read_json(json_file)
    fig=plt.gcf()
    plt.plot(x,y,'ro')
    patient=re.findall(pattern,json_file)[0]
    name=name.format(patient,image_format)
    plt.axis('off')
    plt.savefig(name)
    plt.close(fig)

def image_generator(image_path,json_files,pattern,format_image):
    os.chdir(image_path)
    for i in range(len(json_files)):
        CDT_to_image(json_files[i],pattern,format_image)
def rotate_images(image_path):
    os.chdir(image_path)
    images=os.listdir()
    for image in images:
        image_obj = Image.open(image)
        final_image = image_obj.rotate(180)
        final_image = final_image.transpose(Image.FLIP_LEFT_RIGHT)
        final_image.save(image)

# %%
currentpath='/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ'
json_files=search_json_files_Clock_Test(currentpath)
clean_empties_json(json_files)
pattern="patientID_(.*?)/"
format_image=".png"
image_path='/home/abraham/Escritorio/PAE/pae2019/CLOCK/CDT_images'
image_generator(image_path,json_files,pattern,format_image)
rotate_images('/home/abraham/Escritorio/PAE/pae2019/CLOCK/CDT_images')

# %%
# Out:
# ['/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1858/testID_11481/1858-CD-11481-1558435597080-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1861/testID_11526/1861-CD-11526-1558454421774-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1800/testID_9126/1800-CD-9126-1551696013475-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1836/testID_10864/1836-CD-10864-1556872295049-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1853/testID_11359/1853-CD-11359-1558091618797-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1832/testID_10658/1832-CD-10658-1556265647337-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1843/testID_11039/1843-CD-11039-1557481654943-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1846/testID_11164/1846-CD-11164-1557847542622-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1877/testID_11887/1877-CD-11887-1559305232022-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1842/testID_11028/1842-CD-11028-1557476214859-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1845/testID_11061/1845-CD-11061-1557487977122-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1807/testID_9670/1807-CD-9670-1553257448560-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1806/testID_9658/1806-CD-9658-1553257372303-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1837/testID_10879/1837-CD-10879-1556875328035-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1835/testID_10817/1835-CD-10817-1556805331674-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1818/testID_10156/1818-CD-10156-1554391657463-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1797/testID_9085/1797-CD-9085-1551438003803-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1828/testID_10424/1828-CD-10424-1555063502599-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1830/testID_10626/1830-CD-10626-1556029328441-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1801/testID_9176/1801-CD-9176-1551871341752-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1851/testID_11319/1851-CD-11319-1558082674613-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1821/testID_10196/1821-CD-10196-1554454104218-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1838/testID_10896/1838-CD-10896-1556879516186-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1823/testID_10224/1823-CD-10224-1554460921126-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1798/testID_9099/1798-CD-9099-1551440738071-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1844/testID_11050/1844-CD-11050-1557484414118-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1878/testID_11914/1878-CD-11914-1559549194634-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1814/testID_10095/1814-CD-10095-1554365831680-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1811/testID_10022/1811-CD-10022-1554216046527-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1799/testID_9116/1799-CD-9116-1551445590515-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1817/testID_10143/1817-CD-10143-1554388895055-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1865/testID_11642/1865-CD-11642-1558684028799-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1804/testID_9463/1804-CD-9463-1552910585372-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1860/testID_11515/1860-CD-11515-1558450705879-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1854/testID_11385/1854-CD-11385-1558342824804-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1859/testID_11502/1859-CD-11502-1558447005753-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1833/testID_10687/1833-CD-10687-1556272756577-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1857/testID_11470/1857-CD-11470-1558432992628-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1841/testID_11017/1841-CD-11017-1557473401230-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1819/testID_10168/1819-CD-10168-1554447997469-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1872/testID_11823/1872-CD-11823-1559287463481-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1796/testID_9071/1796-CD-9071-1551435092257-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1803/testID_9453/1803-CD-9453-1552906333907-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1826/testID_10373/1826-CD-10373-1554969364420-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1869/testID_11686/1869-CD-11686-1558692000914-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1871/testID_11708/1871-CD-11708-1558698068360-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1839/testID_10977/1839-CD-10977-1557241812105-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1862/testID_11537/1862-CD-11537-1558457733720-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1805/testID_9618/1805-CD-9618-1553187278141-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1873/testID_11843/1873-CD-11843-1559291492339-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1866/testID_11652/1866-CD-11652-1558684443931-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1874/testID_11854/1874-CD-11854-1559295269978-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1850/testID_11304/1850-CD-11304-1558080134382-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1863/testID_11635/1863-CD-11635-1558684014981-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1820/testID_10183/1820-CD-10183-1554451390957-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1829/testID_10461/1829-CD-10461-1555411356275-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1815/testID_10119/1815-CD-10119-1554373013392-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1822/testID_10211/1822-CD-10211-1554458835060-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1870/testID_11697/1870-CD-11697-1558695355532-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1824/testID_10329/1824-CD-10329-1554823593980-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1847/testID_11189/1847-CD-11189-1557850902782-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1855/testID_11420/1855-CD-11420-1558368689782-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1940/testID_9057/1940-CD-9057-1551374040055-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1868/testID_11664/1868-CD-11664-1558687253117-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1808/testID_9641/1808-CD-9641-1553257290710-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1802/testID_9443/1802-CD-9443-1552906288042-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1876/testID_11876/1876-CD-11876-1559301789431-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1849/testID_11217/1849-CD-11217-1557917347660-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1840/testID_10988/1840-CD-10988-1557245409180-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1864/testID_11550/1864-CD-11550-1558519331370-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1867/testID_11675/1867-CD-11675-1558689556356-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1856/testID_11439/1856-CD-11439-1558426607587-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1895/testID_9027/1895-CD-9027-1551359886311-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1526/testID_7544/1526-CD-7544-18091-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1526/testID_7408/1526-CD-7408-17250-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1526/testID_7300/1526-CD-7300-16712-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1583/testID_8800/1583-CD-8800-1551254389210-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1564/testID_8473/1564-CD-8473-1550775172723-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1548/testID_8088/1548-CD-8088-1550586297094-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1578/testID_8821/1578-CD-8821-1551254441162-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1574/testID_8678/1574-CD-8678-1551132349771-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1893/testID_8996/1893-CD-8996-1551346856650-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1520/testID_7385/1520-CD-7385-17145-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1520/testID_7381/1520-CD-7381-17133-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1520/testID_7141/1520-CD-7141-16026-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1556/testID_8245/1556-CD-8245-1550675833289-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1553/testID_8069/1553-CD-8069-1550586154302-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1527/testID_7390/1527-CD-7390-17163-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1562/testID_8388/1562-CD-8388-1550759146063-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1576/testID_8919/1576-CD-8919-1551268565608-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1524/testID_7211/1524-CD-7211-16283-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1524/testID_7200/1524-CD-7200-16242-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1535/testID_7761/1535-CD-7761-1550154982314-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1545/testID_7910/1545-CD-7910-1550244345622-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1530/testID_7448/1530-CD-7448-17562-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1530/testID_7479/1530-CD-7479-17804-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1530/testID_7427/1530-CD-7427-17447-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1538/testID_7583/1538-CD-7583-18301-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1534/testID_7524/1534-CD-7524-18018-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1534/testID_7530/1534-CD-7530-18041-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1566/testID_8443/1566-CD-8443-1550770094506-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1509/testID_6706/1509-CD-6706-14328-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1568/testID_8568/1568-CD-8568-1550867066986-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1521/testID_7546/1521-CD-7546-18093-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1521/testID_7306/1521-CD-7306-16742-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1519/testID_6985/1519-CD-6985-15389-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1519/testID_6974/1519-CD-6974-15341-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1554/testID_8054/1554-CD-8054-1550586082819-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1518/testID_6952/1518-CD-6952-15248-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1549/testID_8081/1549-CD-8081-1550586232610-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1536/testID_7608/1536-CD-7608-18360-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1533/testID_7532/1533-CD-7532-18054-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1533/testID_7501/1533-CD-7501-17898-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1506/testID_6729/1506-CD-6729-14422-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1577/testID_8811/1577-CD-8811-1551254409397-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1581/testID_8844/1581-CD-8844-1551254568690-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1522/testID_7277/1522-CD-7277-16616-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1580/testID_8832/1580-CD-8832-1551254507538-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1504/testID_6526/1504-CD-6526-13682-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1525/testID_7289/1525-CD-7289-16674-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1525/testID_7373/1525-CD-7373-17098-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1569/testID_8572/1569-CD-8572-1550867119282-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1565/testID_8369/1565-CD-8369-1550759047482-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1891/testID_8962/1891-CD-8962-1551272172335-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1558/testID_8289/1558-CD-8289-1550679750732-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1544/testID_7795/1544-CD-7795-1550155353323-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1894/testID_9022/1894-CD-9022-1551359220910-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1529/testID_7535/1529-CD-7535-18061-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1529/testID_7455/1529-CD-7455-17585-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1529/testID_7510/1529-CD-7510-17945-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1575/testID_8698/1575-CD-8698-1551132433924-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1560/testID_8277/1560-CD-8277-1550678834060-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1547/testID_7976/1547-CD-7976-1550504100134-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1532/testID_7453/1532-CD-7453-17576-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1890/testID_8945/1890-CD-8945-1551268938237-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1510/testID_6808/1510-CD-6808-14686-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1510/testID_6838/1510-CD-6838-14798-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1579/testID_8907/1579-CD-8907-1551268549726-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1511/testID_6797/1511-CD-6797-14655-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1511/testID_6827/1511-CD-6827-14753-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1513/testID_6752/1513-CD-6752-14534-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1531/testID_7439/1531-CD-7439-17520-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1540/testID_7774/1540-CD-7774-1550155236278-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1523/testID_7219/1523-CD-7219-16312-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1523/testID_7274/1523-CD-7274-16608-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1541/testID_7744/1541-CD-7744-1550153391164-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1889/testID_8869/1889-CD-8869-1551258621718-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1563/testID_8368/1563-CD-8368-1550759047164-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1508/testID_6718/1508-CD-6718-14373-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1528/testID_7539/1528-CD-7539-18068-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1528/testID_7398/1528-CD-7398-17185-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1528/testID_7400/1528-CD-7400-17192-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1528/testID_7558/1528-CD-7558-18161-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1537/testID_7755/1537-CD-7755-1550154970031-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1537/testID_7620/1537-CD-7620-18404-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1582/testID_8930/1582-CD-8930-1551268593332-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1552/testID_8063/1552-CD-8063-1550586114153-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1570/testID_8542/1570-CD-8542-1550866945595-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1572/testID_8597/1572-CD-8597-1550883674783-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1572/testID_8563/1572-CD-8563-1550867026639-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1573/testID_8702/1573-CD-8702-1551132468784-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1561/testID_8393/1561-CD-8393-1550759185974-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1555/testID_8215/1555-CD-8215-1550675620960-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1584/testID_6457/1584-CD-6457-13391-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1584/testID_6650/1584-CD-6650-14049-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1584/testID_6941/1584-CD-6941-15212-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1543/testID_7817/1543-CD-7817-1550157399731-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1571/testID_8547/1571-CD-8547-1550866948952-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1512/testID_6742/1512-CD-6742-14489-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1515/testID_6856/1515-CD-6856-14867-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1550/testID_8134/1550-CD-8134-1550592928860-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1892/testID_9011/1892-CD-9011-1551355102001-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1514/testID_6783/1514-CD-6783-14630-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1514/testID_6762/1514-CD-6762-14587-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1514/testID_6818/1514-CD-6818-14740-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1567/testID_8578/1567-CD-8578-1550867160755-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1551/testID_8093/1551-CD-8093-1550586334978-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1546/testID_7965/1546-CD-7965-1550504054147-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1557/testID_8238/1557-CD-8238-1550675801757-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1542/testID_7782/1542-CD-7782-1550155273855-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1896/testID_9142/1896-CD-9142-1551703697097-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1559/testID_8225/1559-CD-8225-1550675641841-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1507/testID_6696/1507-CD-6696-14278-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1516/testID_6982/1516-CD-6982-15382-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/mad pencil y trazo/patientID_1516/testID_6963/1516-CD-6963-15299-migrated.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1875/testID_11865/1875-CD-11865-1559299123112-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1831/testID_10676/1831-CD-10676-1556267496733-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1810/testID_10013/1810-CD-10013-1554214236992-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1852/testID_11347/1852-CD-11347-1558089153183-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1825/testID_10340/1825-CD-10340-1554827113360-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1812/testID_10005/1812-CD-10005-1554214204670-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1809/testID_9858/1809-CD-9858-1553849955574-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1813/testID_10043/1813-CD-10043-1554216722861-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1827/testID_10413/1827-CD-10413-1555061164715-0.json',
#  '/home/abraham/Escritorio/PAE/pae2019/DATABASE/PENCIL TRAZO Y RELOJ/patientID_1834/testID_10806/1834-CD-10806-1556803025651-0.json']
